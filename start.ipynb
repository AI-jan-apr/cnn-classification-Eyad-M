# %% [markdown]
# # Start Here
#
# **Step 1** — Enable `GITHUB_TOKEN` in the Secrets panel (key icon, left sidebar).
#
# **Step 2** — Run the cell below to clone the project.
#
# **Step 3** — Go to `File → Open notebook → Upload` and navigate to `/content/cnn-classification-Eyad-M/notebooks/` to open any notebook.

# %%
from google.colab import userdata
import os

token = userdata.get('GITHUB_TOKEN')
repo_dir = '/content/cnn-classification-Eyad-M'

if not os.path.exists(repo_dir):
    # !git clone https://{token}@github.com/Eyad-M/cnn-classification-Eyad-M {repo_dir}
    print('\nDone! Now go to: File → Open notebook → Upload')
    print(f'Notebooks are at: {repo_dir}/notebooks/')
else:
    # !git -C {repo_dir} pull
    print('Repo updated.')
